# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ML WORK/Advertising.csv')
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df = df.drop(columns=['Unnamed: 0'],axis=1)
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
X=df.drop(columns=['Sales'],axis=1)
y=df['Sales']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=101)

# %%
#scaling data
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(X_train)
X_train=scaler.transform(X_train)
X_test=scaler.transform(X_test)

# %%
from sklearn.linear_model import Ridge
model=Ridge(alpha=100)

# %%
from sklearn.model_selection import cross_val_score
scores=cross_val_score(model,X_train,y_train,scoring='neg_mean_squared_error',cv=5)

# %%
scores
# Out:
# array([ -7.97043864,  -6.37406401, -11.04242236,  -5.02941692,
#         -8.123613  ])

# %%
scores.mean()
# Out:
# np.float64(-7.707990984047884)

# %%
#now fit the model
model.fit(X_train,y_train)
# Out:
# Ridge(alpha=100)

# %%
#model evaluation on test data
from sklearn.metrics import mean_absolute_error,mean_squared_error
y_pred=model.predict(X_test)

# %%
MAE=mean_absolute_error(y_test,y_pred)
MSE=mean_squared_error(y_test,y_pred)
RMSE=np.sqrt(MSE)

# %%
print(MAE)
print(MSE)
print(RMSE)
# Out:
# 1.9660153009275398
# 6.107743569063393
# 2.471384949590693

# %%
model2=Ridge(alpha=1)
scores2=cross_val_score(model2,X_train,y_train,scoring='neg_mean_squared_error',cv=5)
scores2
# Out:
# array([-2.61549235, -2.91048688, -4.67628432, -1.64166698, -4.64284435])

# %%
model2.fit(X_train,y_train)
# Out:
# Ridge(alpha=1)

# %%
#now model2 evaluation
y_pred2=model2.predict(X_test)
MAE2=mean_absolute_error(y_test,y_pred2)
MSE2=mean_squared_error(y_test,y_pred2)
RMSE2=np.sqrt(MSE2)

# %%
print(MAE2)
print(MSE2)
print(RMSE2)
# Out:
# 1.1252494935250195
# 2.069629701531958
# 1.4386207636246453

# %%
#now using cross-validate
from sklearn.model_selection import cross_validate
model=Ridge(alpha=100)
scores=cross_validate(model,X_train,y_train,scoring=['neg_mean_absolute_error','neg_mean_squared_error','max_error'],cv=5)

# %%
scores
# Out:
# {'fit_time': array([0.00202203, 0.00157285, 0.00169873, 0.00151467, 0.00150967]),
#  'score_time': array([0.00237536, 0.0020504 , 0.00184178, 0.00179839, 0.00181198]),
#  'test_neg_mean_absolute_error': array([-2.14671806, -1.79963873, -2.55233938, -1.72110588, -2.20122405]),
#  'test_neg_mean_squared_error': array([ -7.97043864,  -6.37406401, -11.04242236,  -5.02941692,
#          -8.123613  ]),
#  'test_max_error': array([ -6.41694322,  -6.04326768, -10.067773  ,  -6.5363173 ,
#          -7.49239591])}

# %%
scores=pd.DataFrame(scores)
scores
# Out:
#    fit_time  score_time  test_neg_mean_absolute_error  \
# 0  0.002022    0.002375                     -2.146718
# 1  0.001573    0.002050                     -1.799639
# 2  0.001699    0.001842                     -2.552339
# 3  0.001515    0.001798                     -1.721106
# 4  0.001510    0.001812                     -2.201224
#
#    test_neg_mean_squared_error  test_max_error
# 0                    -7.970439       -6.416943
# 1                    -6.374064       -6.043268
# 2                   -11.042422      -10.067773
# 3                    -5.029417       -6.536317
# 4                    -8.123613       -7.492396

# %%
scores.mean()
# Out:
# fit_time                        0.001664
# score_time                      0.001976
# test_neg_mean_absolute_error   -2.084205
# test_neg_mean_squared_error    -7.707991
# test_max_error                 -7.311339
# dtype: float64

# %%
#fit the model now
model.fit(X_train,y_train)
# Out:
# Ridge(alpha=100)

# %%
#predication on test_data
y_pred=model.predict(X_test)

# %%
#model evalaution
MAE=mean_absolute_error(y_test,y_pred)
MSE=mean_squared_error(y_test,y_pred)
RMSE=np.sqrt(MSE)

# %%
print(MAE)
print(MSE)
print(RMSE)
# Out:
# 1.9660153009275398
# 6.107743569063393
# 2.471384949590693

# %%
model2=Ridge(alpha=1)
scores=cross_validate(model2,X_train,y_train,scoring=['neg_mean_absolute_error','neg_mean_squared_error','max_error'],cv=5)

# %%
scores
# Out:
# {'fit_time': array([0.00236845, 0.00186253, 0.00193095, 0.00165272, 0.00205255]),
#  'score_time': array([0.00270796, 0.00233316, 0.00269341, 0.00273609, 0.00252891]),
#  'test_neg_mean_absolute_error': array([-1.37052411, -1.51117589, -1.3596124 , -1.03650629, -1.54718534]),
#  'test_neg_mean_squared_error': array([-2.61549235, -2.91048688, -4.67628432, -1.64166698, -4.64284435]),
#  'test_max_error': array([-3.58971737, -3.01015461, -9.08323448, -2.8620453 , -6.40520044])}

# %%
scores=pd.DataFrame(scores)
scores.mean()
# Out:
# fit_time                        0.001973
# score_time                      0.002600
# test_neg_mean_absolute_error   -1.365001
# test_neg_mean_squared_error    -3.297355
# test_max_error                 -4.990070
# dtype: float64

# %%
#model fiting
model2.fit(X_train,y_train)
# Out:
# Ridge(alpha=1)

# %%
#model evalaution
y_pred=model2.predict(X_test)
MAE=mean_absolute_error(y_test,y_pred)
MSE=mean_squared_error(y_test,y_pred)
RMSE=np.sqrt(MSE)

# %%
print(MAE)
print(MSE)
print(RMSE)
# Out:
# 1.1252494935250195
# 2.069629701531958
# 1.4386207636246453

# %%
#Now studing gridsearcv
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
from sklearn.linear_model import ElasticNet

# %%
model=ElasticNet()

# %%
paramter_grid={'alpha':[0.1,1,5,10,50],'l1_ratio':[.1,.5,.7,.85,.95,1]}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_model=GridSearchCV(estimator=model,param_grid=paramter_grid,scoring='neg_mean_squared_error',cv=5,verbose=2)

# %%
grid_model
# Out:
# GridSearchCV(cv=5, estimator=ElasticNet(),
#              param_grid={'alpha': [0.1, 1, 5, 10, 50],
#                          'l1_ratio': [0.1, 0.5, 0.7, 0.85, 0.95, 1]},
#              scoring='neg_mean_squared_error', verbose=2)

# %%
grid_model.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.7; total time=   0.0s
# ...

# %%
#model evalaution
y_pred=grid_model.predict(X_test)
MAE=mean_absolute_error(y_test,y_pred)

RMSE=np.sqrt(MSE)

# %%
print(MAE)
print(RMSE)
# Out:
# 1.125907256242149
# 1.4453170761718552
