# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **2D DATA OBSERVATION**

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ML WORK/K-MEANS-CLUSTERING UNSUPERVISED LEARNING/student_clustering.csv')

# %%
df.head()
# Out:
#    cgpa   iq
# 0  5.13   88
# 1  5.90  113
# 2  8.36   93
# 3  8.27   97
# 4  5.45  110

# %%
sns.scatterplot(x='cgpa',y='iq',data=df)
# Out:
# <Axes: xlabel='cgpa', ylabel='iq'>

# %%
from sklearn.cluster import KMeans

# %%
#use elbow method to find the value of k
wss=[]
for i in range(1,11):
  km=KMeans(n_clusters=i)
  km.fit(df[['cgpa','iq']])
  wss.append(km.inertia_)

# %%
print(wss)
# Out:
# [29957.898287999997, 4184.141269999999, 2503.3975810000015, 681.9696600000001, 514.1616803171117, 462.46714984084235, 328.3425126175517, 272.0586605649309, 203.47096859372516, 227.9578979155576]

# %%
x=np.arange(1,11)
plt.plot(x,wss)
plt.show()

# %%
X = df.iloc[:,:].values
km = KMeans(n_clusters=4)
y_means = km.fit_predict(X)

# %%
y_means=km1.predict(df[['cgpa','iq']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-36440841.py in <cell line: 0>()
# ----> 1 y_means=km1.predict(df[['cgpa','iq']])
#
# NameError: name 'km1' is not defined

# %%
print(y_means)

# %%
X[y_means == 1,0]

# %%
plt.scatter(X[y_means == 0,0],X[y_means == 0,1],color='blue')
plt.scatter(X[y_means == 1,0],X[y_means == 1,1],color='red')
plt.scatter(X[y_means == 2,0],X[y_means == 2,1],color='green')
plt.scatter(X[y_means == 3,0],X[y_means == 3,1],color='yellow')

# %% [markdown]
# # **3D DATA OBSERVATION**

# %%
from sklearn.datasets import make_blobs

centroids = [(-5,-5,5),(5,5,-5),(3.5,-2.5,4),(-2.5,2.5,-4)]
cluster_std = [1,1,1,1]

X,y = make_blobs(n_samples=200,cluster_std=cluster_std,centers=centroids,n_features=3,random_state=1)

# %%
X

# %%
import plotly.express as px
fig = px.scatter_3d(x=X[:,0], y=X[:,1], z=X[:,2])
fig.show()

# %%
WCC=[]
for i in range(1,11):
  km=KMeans(n_clusters=i)
  km.fit(X)
  WCC.append(km.inertia_)

# %%
plt.plot(np.arange(1,11),WCC)
plt.show()

# %%
km2=KMeans(n_clusters=4)
y_means=km2.fit_predict(X)

# %%
y_means

# %%
df = pd.DataFrame()

df['col1'] = X[:,0]
df['col2'] = X[:,1]
df['col3'] = X[:,2]
df['label'] = y_means

# %%
fig = px.scatter_3d(df,x='col1', y='col2', z='col3',color='label')
fig.show()

# %%
import urllib.request
from PIL import Image

url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML0187EN-SkillsNetwork/labs/module%201/images/peppers.jpg'
with urllib.request.urlopen(url) as url_response:
    img = Image.open(url_response)

plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(639.5), np.float64(479.5), np.float64(-0.5))
